# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...

# %%
# !cd yolov5 && pip install -r requirements.txt
# Out:
# ...
#   Using cached GitPython-3.1.31-py3-none-any.whl (184 kB)
# ...
#   Using cached matplotlib-3.7.1-cp310-cp310-win_amd64.whl (7.6 MB)
# ...
#   Using cached scipy-1.10.1-cp310-cp310-win_amd64.whl (42.5 MB)
# ...
#   Using cached thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# ...
#   Using cached tqdm-4.65.0-py3-none-any.whl (77 kB)
# ...
#   Using cached pandas-2.0.1-cp310-cp310-win_amd64.whl (10.7 MB)
# ...
#   Using cached seaborn-0.12.2-py3-none-any.whl (293 kB)
# ...
#   Using cached setuptools-67.7.2-py3-none-any.whl (1.1 MB)
# ...
#   Using cached gitdb-4.0.10-py3-none-any.whl (62 kB)
# ...
#   Using cached contourpy-1.0.7-cp310-cp310-win_amd64.whl (162 kB)
# ...
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# ...
#   Using cached fonttools-4.39.3-py3-none-any.whl (1.0 MB)
# ...
#   Using cached kiwisolver-1.4.4-cp310-cp310-win_amd64.whl (55 kB)
# ...
#   Using cached pyparsing-3.0.9-py3-none-any.whl (98 kB)
# ...
#   Using cached pytz-2023.3-py2.py3-none-any.whl (502 kB)
# ...
#   Using cached tzdata-2023.3-py2.py3-none-any.whl (341 kB)
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="uGsOY9EcjJTLfV21txyu")
project = rf.workspace("major-project-bbojo").project("major-project-kamim")
dataset = project.version(2).download("yolov5")
# Out:
# ...
# [notice] A new release of pip available: 22.3.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# loading Roboflow workspace...
# loading Roboflow project...
# ...

# %%
# !pip install torch torchvision torchaudio  --extra-index-url https://download.pytorch.org/whl/cu117
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu117
# ...

# %%
print("hello world")
# !pip install opencv-python
# Out:
# hello world
# ...
#   Using cached opencv_python-4.7.0.72-cp37-abi3-win_amd64.whl (38.2 MB)
# ...

# %%
import torch

# Model
model1 = torch.hub.load("ultralytics/yolov5", "yolov5s")  # or yolov5n - yolov5x6, custom
img = "E:/traning/FLIR_00950_jpeg.rf.3964d4a21938a4e0d2cf073320892397.jpg"
results = model1(img)
results.print()
from matplotlib import pyplot as plt
import numpy as np
# %matplotlib inline
plt.imshow(np.squeeze(results.render()))
plt.show()
# Out:
# Using cache found in C:\Users\subit/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2023-5-9 Python-3.10.10 torch-2.0.0+cpu CPU
# requirements: C:\Users\subit\.cache\torch\hub\requirements.txt not found, check failed.
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...
# image 1/1: 640x640 4 cars
# Speed: 264.1ms pre-process, 867.3ms inference, 141.7ms NMS per image at shape (1, 3, 640, 640)

# %%
# !cd yolov5 && python train.py --img 640 --batch -1 --epochs 100 --data E:/traning/yolov5/major-project-2/data.yaml --weights yolov5s.pt --name yolov5s_results

# %%
import torch
import cv2
# !cd yolov5& python detect.py --source E:/traning/yolov5/major-project-2/train/images --weights E:/traning/yolov5/runs/train/yolov5s_results4/weights/best.pt

# %%
import torch
model = torch.hub.load('ultralytics/yolov5', 'custom', path='E:/traning/yolov5/runs/train/yolov5s_results4/weights/best.pt')
# Out:
# Using cache found in C:\Users\subit/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2023-5-9 Python-3.10.10 torch-2.0.0+cpu CPU
# requirements: C:\Users\subit\.cache\torch\hub\requirements.txt not found, check failed.
# Fusing layers...
# Model summary: 157 layers, 7020913 parameters, 0 gradients, 15.8 GFLOPs
# Adding AutoShape...

# %%
model
# Out:
# AutoShape(
#   (model): DetectMultiBackend(
#     (model): DetectionModel(
#       (model): Sequential(
#         (0): Conv(
#           (conv): Conv2d(3, 32, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (2): C3(
#           (cv1): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
# ...

# %%
#img = 'https://ultralytics.com/images/zidane.jpg'
img = "E:/traning/FLIR_00950_jpeg.rf.3964d4a21938a4e0d2cf073320892397.jpg"

# %%
results = model(img)
results.print()
# Out:
# image 1/1: 640x640 15 cars
# Speed: 16.2ms pre-process, 491.9ms inference, 7.0ms NMS per image at shape (1, 3, 640, 640)

# %%
from matplotlib import pyplot as plt
import numpy as np
# %matplotlib inline
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
# !cd yolov5 && val.py --data E:/traning/yolov5/major-project-2/data.yaml --task test

# %%
import cv2

#cap = cv2.VideoCapture(0)
#while cap.isOpened():
#    ret, frame = cap.read()
    
#    cv2.imshow('YOLO',frame)

 #   if cv2.waitKey(10) & 0xFF == ord('q'):
  #    break
#cap.release()
#cv2.destroyAllWindows

cap = cv2.VideoCapture("output_video.mp4")

if not cap.isOpened():
    print("Cannot open camera")
    exit()

while True:

    # Capture frame-by-frame
    ret, frame = cap.read()
    
    results = model1(frame)
    
    cv2.imshow('YOLO', np.squeeze(results.render()))

    # if frame is read correctly ret is True
    if not ret:
        print("Can't receive frame (stream end?). Exiting ...")
        break

    # Display the resulting frame
    

    if cv2.waitKey(1) == ord('q'):
        break

# When everything done, release the capture
cap.release()
cv2.destroyAllWindows()

# %%
# !cd yolov5 && python detect.py --weights E:/traning/yolov5/runs/train/yolov5s_results4/weights/best.pt --source 0
# Out:
# ^C
